# %%
import random
import requests
from datetime import datetime
import time
import os
from dotenv import load_dotenv
import pandas as pd
import logging
from pathlib import Path
from tqdm import tqdm
from stock_api import Buy_Stock, Sell_Stock, Get_User_Stocks

load_dotenv()
log_path = Path("/app/logs/error.log")
log_path.parent.mkdir(parents=True, exist_ok=True)
logging.basicConfig(
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler(log_path, encoding="utf-8"),
        logging.StreamHandler()
    ],
    force=True,
)

ACCOUNT = os.getenv('STOCK_ACCOUNT_USERNAME')
PASSWORD = os.getenv('STOCK_ACCOUNT_PASSWORD')
PG_URI = os.getenv('POSTGRES_URI')

# %%
import twstock
stock = twstock.realtime.get('2330')
stock
# stock
# Out:
# {'timestamp': 1778221800.0,
#  'info': {'code': '2330',
#   'channel': '2330.tw',
#   'name': '台積電',
#   'fullname': '台灣積體電路製造股份有限公司',
#   'time': '2026-05-08 14:30:00'},
#  'realtime': {'latest_trade_price': '2290.0000',
#   'trade_volume': '4746',
#   'accumulate_trade_volume': '26824',
#   'best_bid_price': ['2290.0000',
#    '2285.0000',
#    '2280.0000',
#    '2275.0000',
#    '2270.0000'],
#   'best_bid_volume': ['676', '669', '949', '693', '1254'],
#   'best_ask_price': ['2295.0000',
#    '2300.0000',
#    '2305.0000',
#    '2310.0000',
#    '2315.0000'],
#   'best_ask_volume': ['60', '160', '365', '466', '316'],
#   'open': '2300.0000',
#   'high': '2310.0000',
#   'low': '2265.0000'},
#  'success': True}

# %%
Buy_Stock(ACCOUNT, PASSWORD, stock_code=2330, stock_shares=1, stock_price=2081)
# Out:
# Buying stock...
# Result: success
# Status: buy successfully
# True

# %%
Get_User_Stocks(ACCOUNT, PASSWORD)
# Out:
# [{'usid': 14897,
#   'stock_name': '台積電',
#   'beginning_price': '2144.09091',
#   'shares': 11,
#   'createtime': 1776324912,
#   'stock_code_id': '2330',
#   'user_uid_id': 1349},
#  {'usid': 14970,
#   'stock_name': '南亞科',
#   'beginning_price': '228.50000',
#   'shares': 10,
#   'createtime': 1777534527,
#   'stock_code_id': '2408',
#   'user_uid_id': 1349},
#  {'usid': 14971,
#   'stock_name': '華邦電',
#   'beginning_price': '90.00000',
#   'shares': 10,
#   'createtime': 1777534528,
#   'stock_code_id': '2344',
#   'user_uid_id': 1349},
#  {'usid': 15059,
#   'stock_name': '聯發科',
#   'beginning_price': '3305.00000',
#   'shares': 1,
#   'createtime': 1778139333,
#   'stock_code_id': '2454',
#   'user_uid_id': 1349},
#  {'usid': 15060,
#   'stock_name': '旺宏',
#   'beginning_price': '161.50000',
#   'shares': 1,
#   'createtime': 1778139334,
#   'stock_code_id': '2337',
#   'user_uid_id': 1349}]
